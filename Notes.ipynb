# %% [markdown]
# # Data Sources
#
# ~100,000 bills from 1991 to 2016
#
# **bill data**
#  * WA State Leglislative Web Services API
#   * http://wslwebservices.leg.wa.gov/
#   * Committee Data 1991-92
#   * Committee Member Data 1993-94?
#   * Bill Data 1991-92
#    * Links to full text
#   * Role Call Data 1991-92
#   * Sponsor Data 1991-92
#  * Webscrape Bills by Topics webpage
#   * http://apps.leg.wa.gov/billsbytopic/Results.aspx?year=2017
#   * Bill Topic Data 1991
#
# **legislator data**
#  * Twitter API? Twitter scrape?
#   * Legislator Twitter Data
#  * Campaign Funders
#  * Speeches
#  * General:
#   * Gender
#   * Years in office
#   * Age
#   * Ethnicity/Race
#   * District
#   * Party
#   * Is_majority_leader
#   * Is_minority_leader
#   * Is_president
#   * Is_primary_sponsor
#   * Is_secondary_sponsor

# %% [markdown]
# # Categorical Values
# **Party**
# * Democrat - 0
# * Republican - 1
#
# **Agency**
# * House - 0
# * Senate - 1
#
# **Vote**
# * Nay - 0
# * Yea - 1
# * Undecided - 2
# * Absent - 3

# %% [markdown]
# # DATABASES
#
# ## RAW
#
# **bill_api**
# * name: str
# * biennium: str
# * long_friendly_name: str
# * description: str
# * type: str
# * class: str
# * htm_url: str
# * htm_last_modified_date: str
# * htm_create_date: str
# * bill_id:str
#
# **bill_text_api**
#
#
# **committee_api**
# * committee: str
# * name: str
# * id: str
# * long_name: str
# * agency: str
# * acronym: str
# * biennium: str
#
# **committee_member_api**
# * name: str
# * id: str
# * long_name: str
# * agency: str
# * acronym: str
# * party: str
# * district: str
# * first_name: str
# * last_name: str
# * biennium: str
# * comittee_name: str
#
# **sponsor_api**
# * sponsor_id: str
# * sponsor_name: str
# * sponsor_long_name: str
# * sponsor_agency: str
# * sponsor_type: str
# * sponsor_first_name: str
# * sponsor_last_name: str
#
# **topic_scrape**
# * bill_topic: str
# * bill_topic_expanded: str
# * bill_id: str
#
# **vote_api**
# * voting_agency: str
# * bill_id: str
# * biennium: str
# * motion: str
# * sequence_number: str
# * vote_date: str
# * yea_vote_count: str
# * members_voting_yea: str
# * nay_vote_count: str
# * members_voting_nay: str
# * absent_vote_count: str
# * members_voting_absent: str
# * excused_vote_count: str
# * members_voting_excused: str
# * legislator_id: str
# * legislator_name: str
# * legislator_vote: str
#
#
#
#
# ## STAGING
#
# **bill**
# * biennium: str
# * bill_id: str
# * class: str
# * description: str
# * htm_create_date: str
# * htm_last_modified_date: str
# * htm_url: str
# * long_friendly_name: str
# * name: str
# * type: str
# * bill_num: str
# * bill_num_unique: str
# * sponsor_agency: str
# * primary_sponsor_id: str
# * secondary_sponsors: str
# * bill_unique: str
#
# **bill_text**
# * index: int
# * unique_id: str
# * htm_url: str
# * bill_text: str
#
# **legislator**
# * id: int
# * agency: str
# * district: int
# * first_name: str
# * party: int
# * last_name: str
#
# **loyalty**
# * voter_id
# * loyalty_score
#
# **merged_final**
# * index: int
# * vote: int
# * vote_date: datetime
# * voter_id: int
# * voter_name: str
# * voting_agency: int
# * bill_unique: str
# * unique_id: float
# * biennium: str
# * bill_id: str
# * htm_url: str
# * sponsor_agency: str
# * district: int
# * party: int
# * is_primary_sponsor
# * is_minority_party
# * is_secondary_sponsor
# * sponsor_party
#
# **rep_score**
# * secondary_sponsors
# * bill_num_unique
# * primary_sponsor_id
# * rep_score
#
# **unique_vote_dates**
# * index: int
# * bill_unique: str
# * vote_date: datetime
# * unique_id: int
#
# **vote**
# * sequence_number: int
# * vote: int
# * vote_date: datetime
# * voter_id: int
# * voter_name: str
# * voting_agency: int
# * bill_unique: str
# * year: str

# %% [markdown]
# # Potential Features
#
# **Done**
# * voter features
#  * is_primary_sponsor
#  * is_secondary_sponsor
#  * is_in_minority
#  * partisan_score (average of all sponsor's party)
#  * percent that legislator votes yes on bills sponsored by other party - maverick score
#  * voter_id dummies
#  * district dummies
#
#
#
# **To Make**
# * voter features
#  * percent that legislator votes yes in general
#  * friend recommender
# * bill features
#  * topic dummies
#  * nlp
#  * biennium to int 0 to now
#  * number of sponsors
#
#
#
# **Tabled**
# * date_first_read
# * time_between_first_read_and_vote
#
#
# # Methods to try
# **Try**
# * take just this biennium, or just the past 3
