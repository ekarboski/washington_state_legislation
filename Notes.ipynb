# %% [markdown]
# # Data Sources
#
# ~100,000 bills from 1991 to 2016
#
# **bill data**
#  * WA State Leglislative Web Services API
#   * http://wslwebservices.leg.wa.gov/
#   * Committee Data 1991-92
#   * Committee Member Data 1993-94?
#   * Bill Data 1991-92
#    * Links to full text
#   * Role Call Data 1991-92
#   * Sponsor Data 1991-92
#  * Webscrape Bills by Topics webpage
#   * http://apps.leg.wa.gov/billsbytopic/Results.aspx?year=2017
#   * Bill Topic Data 1991
#
# **legislator data**
#  * Twitter API? Twitter scrape?
#   * Legislator Twitter Data
#  * Campaign Funders
#  * Speeches
#  * General:
#   * Gender
#   * Years in office
#   * Age
#   * Ethnicity/Race
#   * District
#   * Party
#   * Is_majority_leader
#   * Is_minority_leader
#   * Is_president
#   * Is_primary_sponsor
#   * Is_secondary_sponsor

# %% [raw]
# agency
# biennium
# bill_id
# class
# htm_last_modified_date
# htm_url
# bill_name
# bill_type -- take out "passed" information
# sequence_number
# vote_date
# sponsor
# sponsor_party
# sponsor_agency
# google_rating
# reviewing_committees
# date_introducted
# time_from_introduced
# RWC_sections_mentioned_in_bill
# BILL NLP
# category
#
#
#
# voting_legislator
# legislator_party
# legislator_party_is_majority
# is_primary_sponsor
# is_secondary_sponsor
# is_minority_leader
# is_majority_leader
# legislator_district
# legislator_age
# gender
# ethnicity
# is_on_committee
# TWITTER NLP
#
#
#
# vote

# %%
Categorical values:
Party:
    Democrat - 0
    Republican - 1
Agency:
    House - 0 
    Senate - 1
Vote:
    Nay - 0
    Yea - 1
    Undecided - 2
    Absent - 3

# %% [markdown]
# ## DATABASES
#
# ### RAW
#
# **bill_api**
# * name: str
# * biennium: str
# * long_friendly_name: str
# * description: str
# * type: str
# * class: str
# * htm_url: str
# * htm_last_modified_date: str
# * htm_create_date: str
# * bill_id:str
#
# **bill_text_api**
#
#
# **committee_api**
# * committee: str
# * name: str
# * id: str
# * long_name: str
# * agency: str
# * acronym: str
# * biennium: str
#
# **committee_member_api**
# * name: str
# * id: str
# * long_name: str
# * agency: str
# * acronym: str
# * party: str
# * district: str
# * first_name: str
# * last_name: str
# * biennium: str
# * comittee_name: str
#
# **sponsor_api**
# * sponsor_id: str
# * sponsor_name: str
# * sponsor_long_name: str
# * sponsor_agency: str
# * sponsor_type: str
# * sponsor_first_name: str
# * sponsor_last_name: str
#
# **topic_scrape**
# * bill_topic: str
# * bill_topic_expanded: str
# * bill_id: str
#
# **vote_api**
# * voting_agency: str
# * bill_id: str
# * biennium: str
# * motion: str
# * sequence_number: str
# * vote_date: str
# * yea_vote_count: str
# * members_voting_yea: str
# * nay_vote_count: str
# * members_voting_nay: str
# * absent_vote_count: str
# * members_voting_absent: str
# * excused_vote_count: str
# * members_voting_excused: str
# * legislator_id: str
# * legislator_name: str
# * legislator_vote: str
#
#
#
#
# ### STAGING
#
# **bill**
# **legislator**
# **merged_initial**
# **unique_vote_dates**
# **vote**
