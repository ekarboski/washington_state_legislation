# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

import pandas as pd
import numpy as np
from create_staging_tables import create_staging_merged_final_df_STEP_SIX

# %%
engine = create_engine('postgresql://localhost:5432/wa_leg_staging')

# %%
con = engine.connect()

# %%
merged_initial_df = pd.read_sql_query('select * from "merged_initial"',con=engine)

# %%
bill_text_df = pd.read_sql_query('select * from "bill_text"',con=engine)

# %%
legislator_df = pd.read_sql_query('select * from "legislator"',con=engine)

# %%
MERGED_final = create_staging_merged_final_df_STEP_SIX(merged_initial_df, bill_text_df, legislator_df)

# %%
MERGED_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3179504 entries, 0 to 3179503
# Data columns (total 32 columns):
# sequence_number           int64
# vote                      int64
# vote_date                 datetime64[ns]
# voter_id                  int64
# voter_name                object
# voting_agency             int64
# bill_unique               object
# year                      int64
# unique_id                 float64
# biennium                  object
# bill_id                   object
# class                     object
# description               object
# htm_create_date           datetime64[ns]
# htm_last_modified_date    datetime64[ns]
# htm_url                   object
# long_friendly_name        object
# name                      object
# type                      object
# bill_num                  object
# bill_num_unique           object
# sponsor_agency            object
# primary_sponsor_id        object
# secondary_sponsors        object
# index                     int64
# bill_text                 object
# id                        int64
# agency                    float64
# district                  int64
# first_name                object
# party                     int64
# last_name                 object
# dtypes: datetime64[ns](3), float64(2), int64(9), object(18)
# memory usage: 800.5+ MB

# %%
MERGED_final.head()
# Out:
#    sequence_number  vote  vote_date  voter_id    ...     district  first_name party  last_name
# 0               38     1 1993-03-13       636    ...           28     Stanley     0   Flemming
# 1               38     1 1993-03-13       637    ...           12        Dale     1    Foreman
# 2               38     1 1993-03-13       140    ...           47      Elmira     1     Forner
# 3               38     1 1993-03-13       146    ...            7       Steve     1    Fuhrman
# 4               38     1 1993-03-13       157    ...           16        Bill     0      Grant
#
# [5 rows x 32 columns]

# %%
final_df = MERGED_final.drop(['sequence_number', 'unique_id', 'class', 'htm_last_modified_date', 'bill_num_unique'], axis=1)

# %%
fi
