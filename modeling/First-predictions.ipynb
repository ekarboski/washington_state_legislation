# %%
import psycopg2
from sqlalchemy import create_engine

import pandas as pd
import numpy as np
import string

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import log_loss, roc_curve, roc_auc_score
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer


from create_staging_tables import create_loyalty_scores_df
from edit_current_legislator import filter_out_duplicates_from_current_leg
from clean_for_model import prepare_bill_text_for_clean_df

import seaborn as sns
import matplotlib.pyplot as plt
% matplotlib inline

# %%
engine = create_engine('postgresql://localhost:5432/wa_leg_staging')

# %%
merged_final_df = pd.read_sql_query('select * from "merged_final"',con=engine)
bill_text_df_dirty = pd.read_sql_query('select * from "bill_text"',con=engine)
rep_score_df = pd.read_sql_query('select * from "rep_score"',con=engine)
loyalty_df = pd.read_sql_query('select * from "loyalty"',con=engine)

current_df = pd.read_sql_query('select * from "current_clean"',con=engine)
current_bill_text_dirty = pd.read_sql_query('select * from "current_bill_text"',con=engine)
current_legislator_df = pd.read_sql_query('select * from "current_legislator"',con=engine)

# %%
bill_text_df = prepare_bill_text_for_clean_df(bill_text_df_dirty)

# %%
loyalty_df.head()
# Out:
#    loyalty_score  percent_yea  voter_id
# 0       0.177242     0.952786       347
# 1       0.140579     1.060844       360
# 2      -0.182734     0.922963       361
# 3      -0.066394     1.114206       387
# 4       0.083411     0.928034       512

# %%
def create_clean_train(merged_final_df, bill_text_df, rep_score_df, loyalty_df):
    
    # Add bill_text
    clean = merged_final_df.merge(bill_text_df, how='left', on=['unique_id', 'htm_url'])
    clean.drop(['index_x', 'index_y'], axis=1, inplace=True)
    clean.rename(columns={'sponsor_party': 'primary_sponsor_party'}, inplace=True)

    
    # Add rep_score and replace -1 values, then make dem_score
    clean['bill_num'] = clean['bill_id'].apply(lambda x: x.split()[1])
    clean['bill_num_unique'] = clean['biennium'] + ' ' + clean['bill_num']
    clean = clean.merge(rep_score_df, how='left', on='bill_num_unique')

    def replace_with_p_sponsor_party(row):
        primary_sponsor_party = row['primary_sponsor_party']
        if row['rep_score'] == -1:
            return primary_sponsor_party
        else:
            return row['rep_score']
    clean['rep_score'] = clean.apply(replace_with_p_sponsor_party, axis=1)
    clean['dem_score'] = 1 - clean['rep_score']
    
    
#     Add loyalty scores
    clean = clean.merge(loyalty_df, how = 'left', on='voter_id')
    clean.drop('index', axis=1, inplace=True)
    
    
    # Feature Engineering functions
    def create_congress_nums(biennium):
        '''Numbers bienniums so that 1991 is 1 and 1993 is 3.'''
        first_year = int((biennium.split('-'))[0])
        return first_year - 1990
    
    def find_num_sponsors(secondary_sponsors):
        if type(secondary_sponsors) == str:
            return round((len(secondary_sponsors) / 5) + 1)
        else: return 1
        
    def remove_neg(num):
        if num < 0:
            return 0
        else: return num
        
    def count_sections(bill_text):
        sections = []
        for count in range(1, 20):
            section_indicator = '({})'.format(count)
            if section_indicator in bill_text:
                sections.append(count)
        if len(sections) == 0:
            return 0
        return np.max(sections)
    
    def get_bill_type(bill_id):
        bill_type = (bill_id.split(' '))[0]
        return bill_type
    
    # Feature Engineering
    clean['bill_length'] = clean['bill_text'].apply(lambda x: len(x))
    clean['num_sections'] = clean['bill_text'].apply(count_sections)
    clean['congress_num'] = clean['biennium'].apply(create_congress_nums)
    clean['num_sponsors'] = clean['secondary_sponsors'].apply(find_num_sponsors)
    
    clean['vote_year'] = clean['vote_date'].apply(lambda x: x.year)
    clean['first_year_read'] = clean['first_date_read'].apply(lambda x: x.year)
    clean['first_year_read'] = clean['first_year_read'].fillna(clean['vote_year'])
    clean['years_until_vote'] = clean['vote_year'] - clean['first_year_read']
    clean['years_until_vote'] = clean['years_until_vote'].apply(remove_neg)
    
    clean['bill_type'] = clean['bill_id'].apply(get_bill_type)
    grouped = clean.groupby('bill_type').mean()
    bill_type_dct = grouped['vote'].to_dict()
    clean['bill_type_score'] = clean['bill_type'].apply(lambda x: bill_type_dct[x])

    return clean, bill_type_dct

# %%
train_clean, bill_type_dct = create_clean_train(merged_final_df, bill_text_df, rep_score_df, loyalty_df)

# %%
train_clean
# Out:
#          vote  vote_date  voter_id  voting_agency       bill_unique  \
# 0           1 1993-02-16       347              1   1993-94 SB 5426
# 1           1 1993-02-16       360              1   1993-94 SB 5426
# 2           1 1993-02-16       361              1   1993-94 SB 5426
# 3           1 1993-02-16       387              1   1993-94 SB 5426
# 4           1 1993-02-16       512              1   1993-94 SB 5426
# 5           1 1993-02-16       399              1   1993-94 SB 5426
# 6           1 1993-02-16       402              1   1993-94 SB 5426
# 7           1 1993-02-16       403              1   1993-94 SB 5426
# 8           1 1993-02-16       405              1   1993-94 SB 5426
# 9           1 1993-02-16       409              1   1993-94 SB 5426
# 10          2 1993-02-16       423              1   1993-94 SB 5426
# 11          1 1993-02-16       428              1   1993-94 SB 5426
# 12          1 1993-02-16       445              1   1993-94 SB 5426
# 13          1 1993-02-16       446              1   1993-94 SB 5426
# 14          1 1993-02-16       460              1   1993-94 SB 5426
# 15          1 1993-02-16       467              1   1993-94 SB 5426
# 16          1 1993-02-16       475              1   1993-94 SB 5426
# 17          1 1993-02-16       477              1   1993-94 SB 5426
# 18          1 1993-04-06         7              0   1993-94 SB 5426
# 19          1 1993-04-06        11              0   1993-94 SB 5426
# 20          1 1993-04-06        17              0   1993-94 SB 5426
# 21          1 1993-04-06       617              0   1993-94 SB 5426
# 22          1 1993-04-06        23              0   1993-94 SB 5426
# 23          1 1993-04-06        47              0   1993-94 SB 5426
# 24          1 1993-04-06        54              0   1993-94 SB 5426
# 25          1 1993-04-06       618              0   1993-94 SB 5426
# 26          1 1993-04-06        63              0   1993-94 SB 5426
# 27          1 1993-04-06       619              0   1993-94 SB 5426
# 28          1 1993-04-06       620              0   1993-94 SB 5426
# 29          1 1993-04-06        72              0   1993-94 SB 5426
# ...       ...        ...       ...            ...               ...
# 3179270     1 2017-04-20     26170              0  2017-18 SCR 8401
# 3179271     1 2017-04-20     27181              0  2017-18 SCR 8401
# 3179272     1 2017-04-20     15810              0  2017-18 SCR 8401
# 3179273     1 2017-04-20     16462              0  2017-18 SCR 8401
# 3179274     1 2017-04-20     18516              0  2017-18 SCR 8401
# 3179275     1 2018-01-31     14208              1   2017-18 SR 8682
# 3179276     0 2018-01-31      8238              1   2017-18 SR 8682
# 3179277     1 2018-01-31     15780              1   2017-18 SR 8682
# 3179285            56       2018          2018.0              0.0        SR
# 3179286            56       2018          2018.0              0.0        SR
# 3179287            56       2018          2018.0              0.0        SR
# 3179288            56       2018          2018.0              0.0        SR
# 3179289            56       2018          2018.0              0.0        SR
# 3179290            56       2018          2018.0              0.0        SR
# 3179291            56       2018          2018.0              0.0        SR
# 3179292            56       2018          2018.0              0.0        SR
# 3179293            56       2018          2018.0              0.0        SR
# 3179294            56       2018          2018.0              0.0        SR
# 3179295            56       2018          2018.0              0.0        SR
# 3179296            56       2018          2018.0              0.0        SR
# 3179297            56       2018          2018.0              0.0        SR
# 3179298            56       2018          2018.0              0.0        SR
# 3179299            56       2018          2018.0              0.0        SR
#
#         bill_type_score
# 0              0.980216
# 1              0.980216
# 2              0.980216
# 3              0.980216
# 4              0.980216
# 5              0.980216
# 6              0.980216
# 7              0.980216
# 8              0.980216
# 9              0.980216
# 10             0.980216
# 11             0.980216
# 12             0.980216
# 13             0.980216
# 14             0.980216
# 15             0.980216
# 16             0.980216
# 17             0.980216
# 18             0.980216
# 19             0.980216
# 20             0.980216
# 21             0.980216
# 22             0.980216
# 23             0.980216
# 24             0.980216
# 25             0.980216
# 26             0.980216
# 27             0.980216
# 28             0.980216
# 29             0.980216
# ...                 ...
# 3179270        0.892666
# 3179271        0.892666
# 3179272        0.892666
# 3179273        0.892666
# 3179274        0.892666
# 3179275        0.603206
# 3179276        0.603206
# 3179277        0.603206
# 3179278        0.603206
# 3179279        0.603206
# 3179280        0.603206
# 3179281        0.603206
# 3179282        0.603206
# 3179283        0.603206
# 3179284        0.603206
# 3179285        0.603206
# 3179286        0.603206
# 3179287        0.603206
# 3179288        0.603206
# 3179289        0.603206
# 3179290        0.603206
# 3179291        0.603206
# 3179292        0.603206
# 3179293        0.603206
# 3179294        0.603206
# 3179295        0.603206
# 3179296        0.603206
# 3179297        0.603206
# 3179298        0.603206
# 3179299        0.603206
#
# [3179300 rows x 35 columns]

# %%
current_bill_text_df = prepare_bill_text_for_clean_df(current_bill_text_dirty)

# %%
def create_clean_test(current_df, current_bill_text_df, loyalty_df, bill_type_dct):
    
    # Add bill_text
    clean = current_df.merge(current_bill_text_df, how='left', on=['bill_id', 'biennium', 'htm_url'])
    clean.rename(columns={'sponsor_party': 'primary_sponsor_party'}, inplace=True)

    
    # Make dem_score
    clean['dem_score'] = 1 - clean['rep_score']
    
    
#   Add loyalty scores
    clean = clean.merge(loyalty_df, how = 'left', on='voter_id')
    
    # Feature Engineering functions
    def create_congress_nums(biennium):
        '''Numbers bienniums so that 1991 is 1 and 1993 is 3.'''
        first_year = int((biennium.split('-'))[0])
        return first_year - 1990
    
    def find_num_sponsors(secondary_sponsors):
        if type(secondary_sponsors) == str:
            return round((len(secondary_sponsors) / 5) + 1)
        else: return 1
        
    def remove_neg(num):
        if num < 0:
            return 0
        else: return num
        
    def count_sections(bill_text):
        sections = []
        for count in range(1, 20):
            section_indicator = '({})'.format(count)
            if section_indicator in bill_text:
                sections.append(count)
        if len(sections) == 0:
            return 0
        return np.max(sections)
    
    def get_bill_type(bill_id):
        bill_type = (bill_id.split(' '))[0]
        return bill_type
    
    # Feature Engineering
    clean['bill_length'] = clean['bill_text'].apply(lambda x: len(x))
    clean['num_sections'] = clean['bill_text'].apply(count_sections)
    clean['congress_num'] = clean['biennium'].apply(create_congress_nums)

    clean['vote_year'] = 2018
    clean['first_year_read'] = clean['first_date_read'].apply(lambda x: x.year)
    clean['first_year_read'] = clean['first_year_read'].fillna(clean['vote_year'])
    clean['years_until_vote'] = clean['vote_year'] - clean['first_year_read']
    clean['years_until_vote'] = clean['years_until_vote'].apply(remove_neg)
    
    # Filter out duplicate legislators
    clean['current'] = clean.apply(filter_out_duplicates_from_current_leg, axis=1)
    clean = clean[clean['current'] == True]
    
    clean['bill_type'] = clean['bill_id'].apply(get_bill_type)
    clean['bill_type_score'] = clean['bill_type'].apply(lambda x: bill_type_dct[x])

    return clean

# %%
test_clean = create_clean_test(current_df, current_bill_text_df, loyalty_df, bill_type_dct)

# %%
test_clean.columns
# Out:
# Index(['biennium', 'bill_id', 'bill_num', 'bill_unique', 'current', 'district',
#        'first_name', 'htm_create_date', 'htm_url', 'last_name',
#        'long_friendly_name', 'name', 'party', 'primary_sponsor_id',
#        'secondary_sponsors', 'sponsor_agency', 'voter_id', 'voting_agency',
#        'is_primary_sponsor', 'num_sponsors', 'is_minority_party',
#        'is_secondary_sponsor', 'primary_sponsor_party', 'rep_score',
#        'bill_text', 'first_date_read', 'dem_score', 'loyalty_score',
#        'percent_yea', 'bill_length', 'congress_num', 'vote_year',
#        'first_year_read', 'years_until_vote', 'bill_type', 'bill_type_score'],
#       dtype='object')

# %% [markdown]
# ### Current Top Model

# %%
# TRAIN
X_train_t = train_clean[['voter_id', 'voting_agency', 'sponsor_agency', 'district', 
                     'party', 'is_primary_sponsor', 'is_secondary_sponsor', 'is_minority_party', 
                     'primary_sponsor_party', 'rep_score', 'loyalty_score', 'bill_length', 'bill_num', 
                     'num_sponsors', 'years_until_vote', 'percent_yea', 'num_sections', 'bill_type_score']]

y_train_t = train_clean['vote']

# TEST
X_test_t = test_clean[['voter_id', 'voting_agency', 'sponsor_agency', 'district', 
                     'party', 'is_primary_sponsor', 'is_secondary_sponsor', 'is_minority_party', 
                     'primary_sponsor_party', 'rep_score', 'loyalty_score', 'bill_length', 'bill_num', 
                     'num_sponsors', 'years_until_vote', 'percent_yea', 'num_sections', 'bill_type_score']]

# y_test_t = sample_test['vote']

# %%
top_model = RandomForestClassifier(n_estimators=1000, max_depth=11, n_jobs=2, random_state=709)
top_model.fit(X_train_t, y_train_t)
y_pred_t = (top_model.predict_proba(X_test_t))[:, 1]
% time
# Out:
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 9.78 µs

# %%
y_pred_t.min()
# Out:
# 0.10278695233763821

# %%
test_clean['predicted_vote'] = y_pred_t

# %%
label_df = test_clean[['bill_id', 'bill_num', 'biennium', 'voter_id', 'voting_agency', 'predicted_vote', 
                       'rep_score', 'htm_url', 'secondary_sponsors']]

# %%
label_df = label_df.merge(current_legislator_df, how='left', on=['voter_id', 'voting_agency'])

# %%
label_df = label_df[label_df['last_name'].notnull()]

# 150083  ESHB 2299     2299  2017-18     11998              1        0.249148
# 150084  ESHB 2299     2299  2017-18     27290              1        0.244353
# 150085  ESHB 2299     2299  2017-18       652              1        0.691033
# 150086  ESHB 2299     2299  2017-18       394              1        0.325088
# 150087  ESHB 2299     2299  2017-18     11952              1        0.784179
# 150088  ESHB 2299     2299  2017-18     10249              1        0.258845
# 150089  ESHB 2299     2299  2017-18     12003              1        0.249998
# 150090  ESHB 2299     2299  2017-18     28317              1        0.809057
# 150091  ESHB 2299     2299  2017-18      1232              1        0.700052
# 150092  ESHB 2299     2299  2017-18     12084              1        0.732894
# 150093  ESHB 2299     2299  2017-18     27211              1        0.275759
# 150094  ESHB 2299     2299  2017-18     20758              1        0.761933
# 150095  ESHB 2299     2299  2017-18      4006              1        0.742339
#
#         rep_score                                            htm_url  \
# 149949        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149950        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149951        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149952        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149953        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149954        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149955        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149956        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149957        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149958        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149959        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149960        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149961        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149962        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149963        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149964        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149965        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149966        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149967        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149968        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149969        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149970        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149971        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149972        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149973        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149974        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149975        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149976        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149977        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 149978        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# ...           ...                                                ...
# 150066        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150067        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150068        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150069        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150070        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150071        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150072        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150073        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150074        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150075        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150076        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150077        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150078        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150079        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150080        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150081        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150082        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150083        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150084        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150085        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150086        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150087        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150088        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150089        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150090        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150091        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150092        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150093        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150094        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 150095        0.0  http://app.leg.wa.gov/documents/billdocs/2017-...
#
#        secondary_sponsors  district first_name  party   last_name  current
# 149949                           23     Sherry      0    Appleton     True
# 149950                            2     Andrew      1      Barkis     True
# 149951                           11      Steve      0   Bergquist     True
# 149952                           19      Brian      0       Blake     True
# 149953                           42    Vincent      1        Buys     True
# 149954                           26   Michelle      1     Caldier     True
# 149955                           15      Bruce      1    Chandler     True
# 149956                           24       Mike      0     Chapman     True
# 149957                           43      Frank      0       Chopp     True
# 149958                           41       Judy      0    Clibborn     True
# 149959                           34     Eileen      0        Cody     True
# 149960                           12       Cary      1    Condotta     True
# 149961                           20    Richard      1      DeBolt     True
# 149962                           13        Tom      1        Dent     True
# 149963                           22       Beth      0      Doglio     True
# 149964                           22     Laurie      0       Dolan     True
# 149965                            9       Mary      1         Dye     True
# 149966                           39    Carolyn      1      Eslick     True
# 149967                           27       Jake      0         Fey     True
# 149968                           34        Joe      0  Fitzgibbon     True
# 149969                           36       Noel      0       Frame     True
# 149970                           45      Roger      0     Goodman     True
# 149971                            5       Paul      1      Graves     True
# 149972                           33        Mia      0   Gregerson     True
# 149973                           35        Dan      1     Griffey     True
# 149974                            8      Larry      1       Haler     True
# 149975                           23       Drew      0      Hansen     True
# 149976                           47       Mark      1    Hargrove     True
# 149977                           44       Mark      1  Harmsworth     True
# 149978                           17       Paul      1      Harris     True
# ...                   ...       ...        ...    ...         ...      ...
# 150066                           46      David      0      Frockt     True
# 150067                           11        Bob      0    Hasegawa     True
# 150068                           12       Brad      1     Hawkins     True
# 150069                           44      Steve      0       Hobbs     True
# 150070                           15        Jim      1   Honeyford     True
# 150071                           22        Sam      0        Hunt     True
# 150072                           33      Karen      0      Keiser     True
# 150073                           14     Curtis      1        King     True
# 150074                           48      Patty      0     Kuderer     True
# 150075                           21      Marko      0       Liias     True
# 150076                           38       John      0       McCoy     True
# 150077                           30       Mark      1    Miloscia     True
# 150078                            5       Mark      0      Mullet     True
# 150079                           34     Sharon      0      Nelson     True
# 150080                           43      Jamie      0    Pedersen     True
# 150081                           40      Kevin      0      Ranker     True
# 150082                           18        Ann      1      Rivers     True
# 150083                           23  Christine      0      Rolfes     True
# 150084                           37    Rebecca      0     Saldaña     True
# 150085                            9       Mark      1   Schoesler     True
# 150086                           35        Tim      0     Sheldon     True
# 150087                            7     Shelly      1       Short     True
# 150088                           19       Dean      0       Takko     True
# 150089                           24      Kevin      0         Van     True
# 150090                           39      Keith      1     Wagoner     True
# 150091                           16    Maureen      1       Walsh     True
# 150092                           13       Judy      1     Warnick     True
# 150093                           41       Lisa      0     Wellman     True
# 150094                           17      Lynda      1      Wilson     True
# 150095                           25       Hans      1      Zeiger     True
#
# [147 rows x 14 columns]

# %%
engine_label = create_engine('postgresql://localhost:5432/wa_leg_label')

# %%
con = engine_label.connect()

# %%
label_df.to_sql('label_second', con, if_exists='replace', index=False)

# %%
len(label_df)

# %%
engine = create_engine('postgresql://localhost:5432/wa_leg_label')

# %%
labels = pd.read_sql_query('select * from "label"',con=engine_label)

# %%
label_bill_example = labels[labels['bill_num'] == '8408']

# %%
sorted_label = label_bill_example.sort_values('last_name')

# %%
sorted_label
# Out:
#          bill_id bill_num biennium  voter_id  voting_agency  predicted_vote  \
# 445070  SCR 8408     8408  2017-18     14208              1        0.878938
# 444978  SCR 8408     8408  2017-18     10031              0        0.883090
# 445071  SCR 8408     8408  2017-18      8238              1        0.878891
# 444979  SCR 8408     8408  2017-18     24075              0        0.877445
# 445072  SCR 8408     8408  2017-18     15780              1        0.880005
# 445073  SCR 8408     8408  2017-18     14083              1        0.876378
# 444980  SCR 8408     8408  2017-18     17227              0        0.880274
# 445074  SCR 8408     8408  2017-18     15811              1        0.836074
# 444981  SCR 8408     8408  2017-18      8317              0        0.882459
# 445075  SCR 8408     8408  2017-18     17289              1        0.878721
# 445076  SCR 8408     8408  2017-18     17759              1        0.877454
# 444982  SCR 8408     8408  2017-18     15820              0        0.873402
# 444983  SCR 8408     8408  2017-18     20760              0        0.878240
# 445077  SCR 8408     8408  2017-18     14325              1        0.846999
# 444984  SCR 8408     8408  2017-18      3469              0        0.871300
# 444985  SCR 8408     8408  2017-18     26176              0        0.878682
# 445078  SCR 8408     8408  2017-18      1407              1        0.841776
# 444986  SCR 8408     8408  2017-18      1659              0        0.863944
# 445079  SCR 8408     8408  2017-18     17294              1        0.837688
# 444987  SCR 8408     8408  2017-18      8209              0        0.882823
# 444988  SCR 8408     8408  2017-18      1543              0        0.863966
# 444989  SCR 8408     8408  2017-18      8237              0        0.876258
# 445080  SCR 8408     8408  2017-18       972              1        0.831286
# 445081  SCR 8408     8408  2017-18      5156              1        0.848514
# 444850  SCR 8408     8408  2017-18      2143              0        0.862956
# 444867  SCR 8408     8408  2017-18     20761              0        0.877205
# 445082  SCR 8408     8408  2017-18     28022              1        0.853016
# 444884  SCR 8408     8408  2017-18     26175              0        0.878721
# 444901  SCR 8408     8408  2017-18     26174              0        0.878682
# 444918  SCR 8408     8408  2017-18     21490              0        0.869780
# ...          ...      ...      ...       ...            ...             ...
# 445106  SCR 8408     8408  2017-18       394              1        0.834703
# 445107  SCR 8408     8408  2017-18     11952              1        0.876014
# 445047  SCR 8408     8408  2017-18     27504              0        0.877727
# 445048  SCR 8408     8408  2017-18     13577              0        0.879882
# 445049  SCR 8408     8408  2017-18     10039              0        0.883660
# 445050  SCR 8408     8408  2017-18     12017              0        0.877208
# 445051  SCR 8408     8408  2017-18     15809              0        0.879267
# 445052  SCR 8408     8408  2017-18     10546              0        0.877526
# 445053  SCR 8408     8408  2017-18     20756              0        0.878217
# 445055  SCR 8408     8408  2017-18      1218              0        0.875213
# 445108  SCR 8408     8408  2017-18     10249              1        0.854140
# 445056  SCR 8408     8408  2017-18     17243              0        0.881856
# 445057  SCR 8408     8408  2017-18     15006              0        0.836527
# 445058  SCR 8408     8408  2017-18     15816              0        0.881753
# 445041  SCR 8408     8408  2017-18      3483              0        0.878545
# 445059  SCR 8408     8408  2017-18     27975              0        0.881884
# 445109  SCR 8408     8408  2017-18     12003              1        0.853659
# 445060  SCR 8408     8408  2017-18     20757              0        0.873475
# 445061  SCR 8408     8408  2017-18     17218              0        0.877219
# 445062  SCR 8408     8408  2017-18     26170              0        0.876171
# 445110  SCR 8408     8408  2017-18     28317              1        0.877563
# 445063  SCR 8408     8408  2017-18     27181              0        0.877380
# 445111  SCR 8408     8408  2017-18      1232              1        0.857338
# 445112  SCR 8408     8408  2017-18     12084              1        0.881210
# 445113  SCR 8408     8408  2017-18     27211              1        0.835415
# 445064  SCR 8408     8408  2017-18     15810              0        0.877448
# 445114  SCR 8408     8408  2017-18     20758              1        0.878959
# 445065  SCR 8408     8408  2017-18     16462              0        0.882486
# 445066  SCR 8408     8408  2017-18     18516              0        0.875114
# 445115  SCR 8408     8408  2017-18      4006              1        0.872096
#
#         rep_score                                            htm_url  \
# 445070        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 444978        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445071        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 444979        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445072        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445073        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 444980        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445074        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 444981        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445075        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445076        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 444982        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 444983        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445077        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 444984        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 444985        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445078        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 444986        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445079        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 444987        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 444988        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 444989        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445080        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445081        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 444850        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 444867        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445082        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 444884        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 444901        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 444918        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# ...           ...                                                ...
# 445106        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445107        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445047        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445048        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445049        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445050        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445051        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445052        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445053        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445055        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445108        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445056        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445057        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445058        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445041        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445059        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445109        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445060        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445061        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445062        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445110        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445063        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445111        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445112        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445113        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445064        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445114        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445065        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445066        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
# 445115        1.0  http://app.leg.wa.gov/documents/billdocs/2017-...
#
#        secondary_sponsors  district     first_name  party    last_name  \
# 445070                           26            Jan      1        Angel
# 444978                           23         Sherry      0     Appleton
# 445071                           10        Barbara      1       Bailey
# 444979                            2         Andrew      1       Barkis
# 445072                            6        Michael      1  Baumgartner
# 445073                            2          Randi      1       Becker
# 444980                           11          Steve      0    Bergquist
# 445074                            3           Andy      0       Billig
# 444981                           19          Brian      0        Blake
# 445075                           20           John      1        Braun
# 445076                            8         Sharon      1        Brown
# 444982                           42        Vincent      1         Buys
# 444983                           26       Michelle      1      Caldier
# 445077                           36         Reuven      0      Carlyle
# 444984                           15          Bruce      1     Chandler
# 444985                           24           Mike      0      Chapman
# 445078                           32        Maralyn      0        Chase
# 444986                           43          Frank      0        Chopp
# 445079                           49        Annette      0    Cleveland
# 444987                           41           Judy      0     Clibborn
# 444988                           34         Eileen      0         Cody
# 444989                           12           Cary      1     Condotta
# 445080                           29          Steve      0       Conway
# 445081                           27        Jeannie      0    Darneille
# 444850                           20        Richard      1       DeBolt
# 444867                           13            Tom      1         Dent
# 445082                           45          Manka      0      Dhingra
# 444884                           22           Beth      0       Doglio
# 444901                           22         Laurie      0        Dolan
# 444918                            9           Mary      1          Dye
# ...                   ...       ...            ...    ...          ...
# 445106                           35            Tim      0      Sheldon
# 445107                            7         Shelly      1        Short
# 445047                           48        Vandana      0      Slatter
# 445048                           10          Norma      1        Smith
# 445049                           45          Larry      0     Springer
# 445050                           25       Melanie       1    Stambaugh
# 445051                            1          Derek      0     Stanford
# 445052                           12           Mike      1       Steele
# 445053                           31           Drew      1   Stokesbary
# 445055                           47            Pat      0     Sullivan
# 445108                           19           Dean      0        Takko
# 445056                           36           Gael      0     Tarleton
# 445057                           15          David      1       Taylor
# 445058                           24          Steve      0    Tharinger
# 445041                           37  Sharon Tomiko      0       Tomiko
# 445059                           46         Javier      0       Valdez
# 445109                           24          Kevin      0          Van
# 445060                           42         Luanne      1          Van
# 445061                           18        Brandon      1         Vick
# 445062                            6           Mike      1         Volz
# 445110                           39          Keith      1      Wagoner
# 445063                           19            Jim      1        Walsh
# 445111                           16        Maureen      1        Walsh
# 445112                           13           Judy      1      Warnick
# 445113                           41           Lisa      0      Wellman
# 445064                            2           J.T.      1       Wilcox
# 445114                           17          Lynda      1       Wilson
# 445065                           49         Sharon      0        Wylie
# 445066                           26          Jesse      1        Young
# 445115                           25           Hans      1       Zeiger
#
#         current
# 445070     True
# 444978     True
# 445071     True
# 444979     True
# 445072     True
# 445073     True
# 444980     True
# 445074     True
# 444981     True
# 445075     True
# 445076     True
# 444982     True
# 444983     True
# 445077     True
# 444984     True
# 444985     True
# 445078     True
# 444986     True
# 445079     True
# 444987     True
# 444988     True
# 444989     True
# 445080     True
# 445081     True
# 444850     True
# 444867     True
# 445082     True
# 444884     True
# 444901     True
# 444918     True
# ...         ...
# 445106     True
# 445107     True
# 445047     True
# 445048     True
# 445049     True
# 445050     True
# 445051     True
# 445052     True
# 445053     True
# 445055     True
# 445108     True
# 445056     True
# 445057     True
# 445058     True
# 445041     True
# 445059     True
# 445109     True
# 445060     True
# 445061     True
# 445062     True
# 445110     True
# 445063     True
# 445111     True
# 445112     True
# 445113     True
# 445064     True
# 445114     True
# 445065     True
# 445066     True
# 445115     True
#
# [147 rows x 14 columns]

# %%
engine = create_engine('postgresql://localhost:5432/wa_leg_staging')

# %%
legislator_df = pd.read_sql_query('select * from "legislator"',con=engine)

# %%
legislator_df[legislator_df['id'] == 17279]

# %%
current_legislator_df[current_legislator_df['voter_id'] == 17279]
