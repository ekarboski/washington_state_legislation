# %%
import pandas as pd

# %%
dct = {'bill_name': ['2016 Senate Bill 6683: Allowing a public depository to arrange for reciprocal deposits of public funds', '2016 Senate Bill 6679: Concerning the security and authentication of state-issued identification', '2016 Senate Bill 6683: Allowing a public depository to arrange for reciprocal deposits of public funds', '2016 Senate Bill 6679: Concerning the security and authentication of state-issued identification'],
       'category': ['taxes', 'abortion', 'taxes', 'abortion'],
       'sponsor': ['Don Benton', 'Pat Sullivan', 'Don Benton', 'Pat Sullivan'],
       'sponsor party': ['R', 'D', 'R', 'D'],
       'sponsor type': ['Senate', 'House', 'Senate', 'House'],
       'introduction date': ['March 24 2016', 'January 12 2016', 'March 24 2016', 'January 12 2016'],
       'sponsor district': ['Vancouver', 'Covington', 'Vancouver', 'Covington'],
       'congressman': ['Harry Benold', 'Harry Benold', 'Maria Cantwell', 'Maria Cantwell'],
       'congressman type': ['Rep', 'Rep', 'Rep', 'Rep'],
       'congressman party': ['D', 'D', 'R', 'R'],
       'congressman vote': [0, 1, 1, 1]}

# %%
example_df = pd.DataFrame(dct)

# %%
example_df
# Out:
#                                            bill_name  category       sponsor  \
# 0  2016 Senate Bill 6683: Allowing a public depos...     taxes    Don Benton
# 1  2016 Senate Bill 6679: Concerning the security...  abortion  Pat Sullivan
# 2  2016 Senate Bill 6683: Allowing a public depos...     taxes    Don Benton
# 3  2016 Senate Bill 6679: Concerning the security...  abortion  Pat Sullivan
#
#   sponsor party sponsor type introduction date sponsor district  \
# 0             R       Senate     March 24 2016        Vancouver
# 1             D        House   January 12 2016        Covington
# 2             R       Senate     March 24 2016        Vancouver
# 3             D        House   January 12 2016        Covington
#
#       congressman congressman type congressman party  congressman vote
# 0    Harry Benold              Rep                 D                 0
# 1    Harry Benold              Rep                 D                 1
# ...

# %%
bill_data = ['bill_name', 'category', 'sponsor', 'sponsor_party', 'sponsor_type', 'sponsor district',
             'introduction_date', 'vote_date', 'bill_text']

# %%
congressman_data = ['c_name', 'c_type', 'c_party', 'c_twitter_nlp', 'c_speeches_nlp', 'c_campaign_funders']

# %%
data_sources = {'bill_data': 'WA State Legislative Web Services API', 'congressman_data': '', 
                'congressman_twitter': '', 'c_campaign_funders': '', 'c_speeches': ''}

# %% [markdown]
# # Data Sources
#
# ~100,000 bills from 1991 to 2016
#
# **bill data**
#  * WA State Leglislative Web Services API
#   * http://wslwebservices.leg.wa.gov/
#   * Committee Data 1991-92
#   * Committee Member Data 1993-94?
#   * Bill Data 1991-92
#    * Links to full text
#   * Role Call Data 1991-92
#   * Sponsor Data 1991-92
#  * Webscrape Bills by Topics webpage
#   * http://apps.leg.wa.gov/billsbytopic/Results.aspx?year=2017
#   * Bill Topic Data 1991
#
# **legislator data**
#  * Twitter API? Twitter scrape?
#   * Legislator Twitter Data
#  * Campaign Funders
#  * Speeches
#  * General:
#   * Gender
#   * Years in office
#   * Age
#   * Ethnicity/Race
#   * District
#   * Party
#   * Is_majority_leader
#   * Is_minority_leader
#   * Is_president
#   * Is_primary_sponsor
#   * Is_secondary_sponsor

# %% [raw]
# agency
# biennium
# bill_id
# class
# htm_last_modified_date
# htm_url
# bill_name
# bill_type -- take out "passed" information
# sequence_number
# vote_date
# sponsor
# sponsor_party
# sponsor_agency
# google_rating
# reviewing_committees
# date_introducted
# time_from_introduced
# RWC_sections_mentioned_in_bill
# BILL NLP
# category
#
#
#
# voting_legislator
# legislator_party
# legislator_party_is_majority
# is_primary_sponsor
# is_secondary_sponsor
# is_minority_leader
# is_majority_leader
# legislator_district
# legislator_age
# gender
# ethnicity
# is_on_committee
# TWITTER NLP
#
#
#
# vote
