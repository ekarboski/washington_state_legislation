# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

import pandas as pd
import numpy as np

# %%
engine = create_engine('postgresql://localhost:5432/wa_leg_staging')

# %%
legislator_df = pd.read_sql_query('select * from "legislator"',con=engine)

# %%
current_house = ['Sherry', 'Barkis', 'Bergquist', 'Blake', 'Buys', 'Caldier', 
                 'Chandler', 'Chapman', 'Chopp', 'Clibborn', 'Cody', 'Condotta', 
                'Debolt', 'Dent', 'Doglio', 'Dolan', 'Dye', 'Eslick', 'Fey', 'Fitzgibbon',
                'Frame', 'Goodman', 'Graves', 'Gregerson', 'Griffey', 'Haler', 'Hansen']

# %%
legislator_df[legislator_df['last_name'].isin(current_house)]
# Out:
#         id  agency  district first_name  party   last_name
# 17      75   House        13       Gary      1    Chandler
# 137    168  Senate        13      Frank      0      Hansen
# 176    169  Senate        13      Wanda      0      Hansen
# 210    638   House        13       Mick      0      Hansen
# 251   1659   House        43      Frank      0       Chopp
# 254   1543   House        11     Eileen      0        Cody
# 255   1543   House        34     Eileen      0        Cody
# 349   3469   House        15      Bruce      1    Chandler
# 421   8209   House        41       Judy      0    Clibborn
# 422   8237   House        12       Cary      1    Condotta
# 439   8317   House        19      Brian      0       Blake
# 453   9996   House         8      Larry      1       Haler
# 472  11999   House        45      Roger      0     Goodman
# 529  13198   House        34        Joe      0  Fitzgibbon
# 532  17241   House        27       Jake      0         Fey
# ...
