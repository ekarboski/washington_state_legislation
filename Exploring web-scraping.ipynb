# %% [markdown]
# ### Trying to webscrape

# %%
from selenium.webdriver import (Chrome, Firefox)
import pandas as pd

from bs4 import BeautifulSoup
from web_scrape_functions import scrape_bill_topic_table

import psycopg2 as pg2
import sqlalchemy
from functools import reduce

# %% [markdown]
# # Scrape topic data for all years and put in raw table

# %%
years = ['1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000'
         '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', 
         '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']

# %%
topic_dfs = [scrape_bill_topic_table(y) for y in years]

# %%
engine = sqlalchemy.create_engine('postgresql://emilykarboski@localhost:5434/wa_leg_raw')
con = engine.connect()
table_name = 'topic_scrape'
# Out:
# ------------------------------------------------------------------
# OperationalError                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in unique_connection(self)
#     344         """
# --> 345         return _ConnectionFairy._checkout(self)
#     346
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# /anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# ...
